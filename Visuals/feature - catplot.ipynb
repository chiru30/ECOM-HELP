# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("delivery.csv")

# %%
df.shape
# Out:
# (10999, 12)

# %%
df.columns
# Out:
# Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms',
#        'Reached.on.Time_Y.N'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
df.head(3)
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1

# %%
df.drop(['ID'], axis=1,inplace= True)

# %%
#df.replace(to_replace ="F",value ="E",inplace=True)

# %%
#df.Warehouse_block.unique()

# %%
df.drop(['Warehouse_block'], axis=1,inplace= True)

# %%
df.Prior_purchases.unique()
# Out:
# array([ 3,  2,  4,  6,  5,  7, 10,  8])

# %%
df.describe()
# Out:
#        Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count         10999.000000     10999.000000         10999.000000
# mean              4.054459         2.990545           210.196836
# std               1.141490         1.413603            48.063272
# min               2.000000         1.000000            96.000000
# 25%               3.000000         2.000000           169.000000
# 50%               4.000000         3.000000           214.000000
# 75%               5.000000         4.000000           251.000000
# max               7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# std           1.522860         16.205527    1635.377251             0.490584
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
colors= ["#10374a", "#3e6f87", '#5b6d75', '#7e8487', '#dce1e3']
sns.set_palette("Greys_r")
sns.palplot(colors)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df['Mode_of_Shipment'],edgecolor=colors[2])
# Out:
# <AxesSubplot:xlabel='Mode_of_Shipment', ylabel='count'>

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df['Customer_care_calls'])
# Out:
# <AxesSubplot:xlabel='Customer_care_calls', ylabel='count'>

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df['Customer_rating'])
# Out:
# <AxesSubplot:xlabel='Customer_rating', ylabel='count'>

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df['Prior_purchases'],edgecolor=colors[0])
# Out:
# <AxesSubplot:xlabel='Prior_purchases', ylabel='count'>

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=df['Product_importance'])
# Out:
# <AxesSubplot:xlabel='Product_importance', ylabel='count'>

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df['Discount_offered'],edgecolor=colors[2])
# Out:
# <AxesSubplot:xlabel='Discount_offered', ylabel='count'>

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['Reached.on.Time_Y.N'])
# Out:
# <AxesSubplot:xlabel='Reached.on.Time_Y.N', ylabel='count'>

# %%
colors1= ["#10374a", "#3e6f87", '#5b6d75', '#7e8487', '#dce1e3']
sns.set_palette("vlag")
sns.palplot(colors)

# %%
sns.pairplot(df,hue='Reached.on.Time_Y.N',)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.catplot("Mode_of_Shipment", hue="Reached.on.Time_Y.N", data=df, kind="count", aspect=1.5, palette="Pastel2_r")

# %%
sns.catplot("Product_importance", hue="Reached.on.Time_Y.N", data=df, kind="count", aspect=1.5, palette="Pastel2_r")

# %%
sns.catplot("Customer_care_calls", hue="Reached.on.Time_Y.N", data=df, kind="count", aspect=1.5, palette="Pastel2_r")

# %%
sns.catplot("Customer_rating", hue="Reached.on.Time_Y.N", data=df, kind="count", aspect=1.5, palette="Pastel2_r")

# %%
sns.catplot("Prior_purchases", hue="Reached.on.Time_Y.N", data=df, kind="count", aspect=1.5, palette="Pastel2_r")

# %%
sns.catplot("Gender", hue="Reached.on.Time_Y.N", data=df, kind="count", aspect=1.5, palette="Pastel2_r")

# %%
sns.catplot("Discount_offered", hue="Reached.on.Time_Y.N", data=df, kind="count", aspect=5, palette="Pastel2_r")
